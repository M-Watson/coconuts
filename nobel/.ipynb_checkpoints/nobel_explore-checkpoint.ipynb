# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from matplotlib import pyplot as plt

# %%
phys_prize_list_url = "https://www.nobelprize.org/prizes/lists/all-nobel-prizes-in-physics/"

# %%
page_request = requests.get(phys_prize_list_url)

page_request_content = page_request.content
page_request_text = page_request.text

# %%
soup = bs(page_request_text, "lxml")
all_divs = soup.findAll('div')
div_by_year = soup.findAll('div', {"class": "by_year"})

# %%
d = div_by_year

# %%
d[2]
# Out:
# <div class="by_year">
# <h3><a href="https://www.nobelprize.org/prizes/physics/2016/">The Nobel Prize in Physics 2016</a></h3>
# <p><a href="https://www.nobelprize.org/prizes/physics/2016/thouless/facts/">David J. Thouless</a>, <a href="https://www.nobelprize.org/prizes/physics/2016/haldane/facts/">F. Duncan M. Haldane</a> and <a href="https://www.nobelprize.org/prizes/physics/2016/kosterlitz/facts/">J. Michael Kosterlitz </a>“for theoretical discoveries of topological phase transitions and topological phases of matter”</p>
# </div>

# %%
forthe = []
items_2 = []
items_3 = []
a = "for"
b = "in"
i = 1

for i in range(len(d)-1):
    lines = []
    i +=1
    for line in d[i]:
        lines.append(line) 
        
    items = []
    for item in lines:
        items.append(item)
        for item_2 in item:
            items_2.append(item_2)        
            for item_3 in item_2:
                items_3.append(item_3)

# %%
for it in items_2:
    if a in it or b in it:
        forthe.append(it)
new_list = []

for line in forthe:
    new_list.append(line.split())

# %%
ii = 0
jj = 0
l = []
for ii in range(len(new_list)):
    for jj in range(len(new_list[ii])):
        l.append(new_list[ii][jj])
        jj +=1
    ii+=1

# %%
from collections import Counter
counts = Counter(l)



df = pd.DataFrame.from_dict(counts.most_common(30), orient='index')
df.plot(kind='bar').show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-163-ccb22be88e95> in <module>()
#       4
#       5
# ----> 6 df = pd.DataFrame.from_dict(counts.most_common(30), orient='index')
#       7 df.plot(kind='bar').show()
#
# C:\Users\mwatson\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype)
#     800             if len(data) > 0:
#     801                 # TODO speed up Series case
# --> 802                 if isinstance(list(data.values())[0], (Series, dict)):
#     803                     data = _from_nested_dict(data)
#     804                 else:
#
# AttributeError: 'list' object has no attribute 'values'

# %%
aa = []
for ij in counts:
    aa.append([ij,counts[ij]])

# %%
x = []
y = []
i = 0
for item in aa:
    if i > 20:
        if i < 34:
            x.append(item[0])
            y.append(item[1])
    i+=1

# %%
x
# Out:
# ['forces”',
#  'background',
#  'through',
#  'nucleons”',
#  'transmutation',
#  'CCD',
#  'current”',
#  'allocated',
#  'polymers”',
#  'technology”',
#  'the',
#  'mass',
#  'W']

# %%
plt.clf()
plt.figure(figsize=(40,20))
plt.bar(x,y).show()
plt.xticks(x, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-208-d2aad2a07cdb> in <module>()
#       1 plt.clf()
#       2 plt.figure(figsize=(40,20))
# ----> 3 plt.bar(x,y).show()
#       4 plt.xticks(x, y)
#
# AttributeError: 'BarContainer' object has no attribute 'show'
