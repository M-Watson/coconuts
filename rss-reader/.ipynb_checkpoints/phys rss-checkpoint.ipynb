# %%
import xml.etree.ElementTree as ET
import requests

# %%
url = 'https://phys.org/rss-feed/'

headers = {
    'User-Agent': 'My User Agent 1.0',
    'From': 'youremail@domain.com'  # This is another valid field
}

response = requests.get(url, headers=headers)

xml = response.content

# %%
tree = ET.fromstring(xml)

# %%
tree.attrib
# Out:
# {'version': '2.0'}

# %%
response
# Out:
# <Response [200]>

# %%
for child in tree:
    print(child.tag, child.text)
# Out:
# channel

# %%
tree[0][4].tag
# Out:
# 'item'

# %%
for item in tree[0].iter('item'):
    title = item[0].text
    description = item[1].text
    link = item[2].text
    category = item[3].text
    pubDate = item[4].text
    guid = item[5].text
    media = item[6].text
    
    
    print('title: {} \n\n\tDescription: {} \n\n\tlink: {}\n'.format(title,description,link))
# Out:
# title: Clover improves soil quality, feeds biofuels crop
#
# 	Description: A four-leaf clover might bring good luck, but a stand of Kura clover can produce healthier soil—in the long run, according to a South Dakota State University study.
#
# 	link: https://phys.org/news/2019-03-clover-soil-quality-biofuels-crop.html
#
# title: Large Hadron Collider pushing computing to the limits
#
# 	Description: At the end of 2018, the Large Hadron Collider (LHC) completed its second multi-year run ("Run 2") that saw the machine reach a proton–proton collision energy of 13 TeV, the highest ever reached by a particle accelerator. During this run, from 2015 to 2018, LHC experiments produced unprecedented volumes of data with the machine's performance exceeding all expectations.
#
# 	link: https://phys.org/news/2019-03-large-hadron-collider-limits.html
#
# title: Catastrophic outlook for African savannahs due to rise in CO2 levels
#
# ...

# %%
walkAll = tree.getiterator(tag=None)
hit_item = False
for  elt in walkAll:
    elt_print = '{}: {}'.format(elt.tag,elt.text)
    if elt.tag == 'item': hit_item =True
    
    if hit_item != True:
        print(elt_print)
    
    elif elt.tag == 'item':
        print('\t\t{}'.format(elt_print))
        
    else:
        print('\t\t\t{}\n'.format(elt_print))
# Out:
# rss:
#
# channel:
#
#
# title: Phys.org - latest science and technology news stories
# link: https://phys.org/
# language: en-us
# description: Phys.org internet news portal provides the latest news on science including: Physics, Nanotechnology, Life Sciences, Space Science, Earth Science, Environment, Health and Medicine.
# 		item:
#
# 			title: Smart solutions to join carbon fiber reinforced plastics and metal
#
# 			description: The engineering of lightweight vehicles requires manufacturers to combine functional metal components with lightweight, highly durable carbon fiber reinforced plastics. Fraunhofer researchers have developed a variety of solutions for joining such disparate materials – and will be showcasing their technology at this year's Hannover Messe on April 1-5, 2019 using an e-scooter demonstrator (Hall 17, Booth C24).
#
# 			link: https://phys.org/news/2019-03-smart-solutions-carbon-fiber-plastics.html
#
# 			category: Engineering
#
# ...

# %%
import json
import xmljson 

#Third party (https://stackoverflow.com/questions/191536/converting-xml-to-json-using-python, 
#https://pypi.org/project/xmljson/)
import pandas as pd

# %%
xml2 = ET.fromstring(response.text)
a = json.dumps(xmljson.badgerfish.data(xml2))

# %%
obj = json.loads(a)

# %%
i = 0
article_list = []
for i in range(len(obj['rss']['channel']['item'])):
    
    article = obj['rss']['channel']['item'][i]
    article_list.append(article)

# %%
df = pd.DataFrame(article_list)

# %%
df.hist('category')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-a960ab4fd8f6> in <module>()
# ----> 1 df.hist('category')
#
# C:\Users\mwatson\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\plotting.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2891     fig, axes = _subplots(naxes=naxes, ax=ax, squeeze=False,
#    2892                           sharex=sharex, sharey=sharey, figsize=figsize,
# -> 2893                           layout=layout)
#    2894     _axes = _flatten(axes)
#    2895
#
# C:\Users\mwatson\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#    3378
#    3379     # Create first subplot separately, so we can share it if requested
# ...

# %%
walkAll = tree.getiterator(tag=None)
hit_item = False
item_list = []
for  elt in walkAll:
    elt_print = '{}: {}'.format(elt.tag,elt.text)
    if elt.tag == 'item': hit_item =True
    
    if hit_item != True:
        pass
    
    elif elt.tag == 'item':
        new_item = {}
        #print('\t\t{}'.format(elt_print))
        
    elif elt.tag !='item' and  hit_item==True:
        new_item[elt.tag] =  elt.text
        #print('\t\t\t{}\n'.format(elt_print))
        
    try:
        item_list.append(new_item)
    except:
        pass

# %%
df = pd.DataFrame(item_list)

# %%
df
# Out:
#                    category  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6              Engineering
# 7              Engineering
# 8              Engineering
# 9              Engineering
# 10             Engineering
# 11             Engineering
# 12             Engineering
# 13             Engineering
# 14             Engineering
# 15             Engineering
# 16             Engineering
# 17             Engineering
# 18             Engineering
# 19             Engineering
# 20             Engineering
# 21             Engineering
# 22     Cell & Microbiology
# 23     Cell & Microbiology
# 24     Cell & Microbiology
# 25     Cell & Microbiology
# 26     Cell & Microbiology
# 27     Cell & Microbiology
# 28     Cell & Microbiology
# 29     Cell & Microbiology
# ..                      ...
# 216  Archaeology & Fossils
# 217  Archaeology & Fossils
# ...

# %%
url_dc = 'https://www.dcpolicycenter.org/publications/feed/'

headers = {
    'User-Agent': 'My User Agent 1.0',
    'From': 'youremail@domain.com'  # This is another valid field
}

response_dc = requests.get(url_dc, headers=headers)

xml_dc = response_dc.content

# %%
tree = ET.fromstring(xml_dc)

# %%
walkAll = tree.getiterator(tag=None)
hit_item = False
item_list = []
new_item = {}
for  elt in walkAll:
    elt_print = '{}: {}'.format(elt.tag,elt.text)
    if elt.tag == 'item': hit_item =True
    
    if hit_item != True:
        pass
    
    elif elt.tag == 'item':
        new_item = {}
        #print('\t\t{}'.format(elt_print))
        
    elif elt.tag !='item' and  hit_item==True:
        new_item[elt.tag] =  elt.text
        #print('\t\t\t{}\n'.format(elt_print))
        
    try:
        item_list.append(new_item)
    except:
        pass

# %%
dcdf = pd.DataFrame(item_list)

# %%
dcdf.tail(20)
# Out:
#                         category  \
# 102  Education Policy Initiative
# 103  Education Policy Initiative
# 104  Education Policy Initiative
# 105  Education Policy Initiative
# 106  Education Policy Initiative
# 107  Education Policy Initiative
# 108  Education Policy Initiative
# 109  Education Policy Initiative
# 110  Education Policy Initiative
# 111  Education Policy Initiative
# 112  Education Policy Initiative
# 113  Education Policy Initiative
# 114  Education Policy Initiative
# 115  Education Policy Initiative
# 116  Education Policy Initiative
# 117  Education Policy Initiative
# 118  Education Policy Initiative
# 119  Education Policy Initiative
# 120  Education Policy Initiative
# 121  Education Policy Initiative
#
#                                               comments  \
# 102  https://www.dcpolicycenter.org/publications/no...
# 103  https://www.dcpolicycenter.org/publications/no...
# 104  https://www.dcpolicycenter.org/publications/no...
# ...
